# %%
import pandas as pd 
import numpy as np
import scipy as scp
import matplotlib as mlp
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn import preprocessing
import xgboost as xgb
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\Ankit\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df=pd.read_csv('data_stocks.csv')

# %%
df.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN    ...     NYSE.WYN  \
# 0    102.2300      85.2200       59.760       121.52    ...       84.370
# 1    102.1400      85.6500       59.840       121.48    ...       84.370
# 2    102.2125      85.5100       59.795       121.93    ...       84.585
# 3    102.1400      85.4872       59.620       121.44    ...       84.460
# 4    102.0600      85.7001       59.620       121.60    ...       84.470
#
#    NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# ...

# %%
DATE=df['DATE']

# %%
date=DATE
a=[int(str(i)[0:4]) for i in date]
b=[int(str(i)[4:7]) for i in date]
c=[int(str(i)[7:]) for i in date]
df1=pd.DataFrame()
df1['a']=a
df1['b']=b
df1['c']=c
df1.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object

# %%
for i in df.columns[1:]:
   Y=df[i]
   X_train, X_test, y_train, y_test = train_test_split(df1, Y, test_size=0.24, random_state=42)
               
               # use DMatrix for xgbosot
   import xgboost as xgb
           
           
   bst = xgb.XGBRegressor(max_depth=4, learning_rate=0.1, n_estimators=1000, silent=True, objective='reg:linear', )
   bst.fit(X_train,y_train)
   best_preds = bst.predict(X_test)
   print(i,r2_score(y_test,best_preds),mean_absolute_error(y_test,best_preds))
# Out:
# SP500 0.9992773054002957 0.7911571358873308
# NASDAQ.AAL 0.9993652010376802 0.06040344297011565
# NASDAQ.AAPL 0.9993523510710433 0.11291402934726107
# NASDAQ.ADBE 0.9994809272927889 0.11195018043579684
# NASDAQ.ADI 0.9967894174552804 0.07843175337487929
# NASDAQ.ADP 0.9991612553593316 0.08203219315832383
# NASDAQ.ADSK 0.9996328572490928 0.12930835169482502
# NASDAQ.AKAM 0.999763489419877 0.05129028583273941
# NASDAQ.ALXN 0.9994724847324339 0.17627537161190793
# NASDAQ.AMAT 0.9991501514659923 0.0499963543123113
# NASDAQ.AMD 0.9987454882498525 0.029276890769952334
# NASDAQ.AMGN 0.9993003652363713 0.13044946897688517
# NASDAQ.AMZN 0.9991829846485663 0.7940817718555164
# NASDAQ.ATVI 0.9996248085782602 0.06374879925100795
# NASDAQ.AVGO 0.9992781204920934 0.24213036559664206
# NASDAQ.BBBY 0.9998276552363365 0.034859145720671385
# NASDAQ.BIIB 0.9992125001419022 0.2709809169861728
# NASDAQ.CA 0.9991210200573135 0.02414330116820451
# NASDAQ.CBOE 0.9997647263159583 0.06315544999820547
# ...

# %%
df2=pd.read_csv('CSV.csv')
df2.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2018-05-14  25.700001  25.790001  25.469999  25.540001  25.540001  106100
# 1  2018-05-15  25.480000  25.559999  25.299999  25.330000  25.330000   96700
# 2  2018-05-16  25.360001  25.610001  25.180000  25.549999  25.549999  149600
# 3  2018-05-17  25.549999  25.639999  25.340000  25.480000  25.480000   79800
# 4  2018-05-18  25.400000  25.670000  25.330000  25.549999  25.549999  124300

# %%
date=df2['Date']
a,b,c=[],[],[]
for i in date.str.split('-'):
    a.append(int(i[0]))
    b.append(int(i[1]))
    c.append(int(i[2]))

# %%
df3=pd.DataFrame()
df3['a']=a
df3['b']=b
df3['c']=c
df3.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object

# %%
df3.head()
# Out:
#       a  b   c
# 0  2018  5  14
# 1  2018  5  15
# 2  2018  5  16
# 3  2018  5  17
# 4  2018  5  18

# %%
for i in df2.columns[1:5]:
   Y=df2[i]
   X_train, X_test, y_train, y_test = train_test_split(df3, Y, test_size=0.24, random_state=42)
               
   import xgboost as xgb
           
           
   bst = xgb.XGBRegressor(max_depth=4, learning_rate=0.1, n_estimators=1000, silent=True, objective='reg:linear', )
   bst.fit(X_train,y_train)
   best_preds = bst.predict(X_test)
   print(i,r2_score(y_test,best_preds),mean_absolute_error(y_test,best_preds))
# Out:
# Open 0.6895158798623735 0.17648958978271523
# High 0.6045694695254122 0.1473665914103197
# Low 0.6165568978851468 0.16995270910644442
# Close 0.344222953263587 0.1838429882405599

# %%
y_test-best_preds
# Out:
# 0    -0.007334
# 17    0.050272
# 15   -0.397978
# 1    -0.217335
# 8    -0.160221
# 5     0.269918
# Name: Close, dtype: float64

# %%
df4=pd.read_csv('stock.csv')

# %%
df4
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0    5-Apr-18  92.440002  93.070000  91.400002  92.379997  29771900  92.379997
# 1    4-Apr-18  87.849998  92.760002  87.730003  92.330002  35560000  92.330002
# 2    3-Apr-18  89.580002  90.050003  87.889999  89.709999  37213800  89.709999
# 3    2-Apr-18  90.470001  90.879997  87.510002  88.519997  48515400  88.519997
# 4   29-Mar-18  90.180000  92.290001  88.400002  91.269997  45867500  91.269997
# 5   28-Mar-18  89.820000  91.230003  88.870003  89.389999  52501100  89.389999
# 6   27-Mar-18  94.940002  95.139999  88.510002  89.470001  56569000  89.470001
# 7   26-Mar-18  90.610001  94.000000  90.400002  93.779999  56396800  93.779999
# 8   23-Mar-18  89.500000  90.459999  87.080002  87.180000  44068900  87.180000
# 9   22-Mar-18  91.269997  91.750000  89.660004  89.790001  38604700  89.790001
# 10  21-Mar-18  92.930000  94.050003  92.209999  92.480003  24457100  92.480003
# ...

# %%
date=df4['Date']
a,b,c=[],[],[]
for i in date.str.split('-'):
    a.append(int(i[0]))
    b.append(i[1])
    c.append(int(i[2]))

# %%
set(b)
# Out:
# {'Apr', 'Feb', 'Jan', 'Mar'}

# %%
m={'Jan':1,'Feb':2,'Mar':3,'Apr':4}

# %%
b=[m[i] for i in b]

# %%
df5=pd.DataFrame()
df5['a']=a
df5['b']=b
df5['c']=c
df5.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object

# %%
for i in df4.columns[1:7]:
   Y=df4[i]
   X_train, X_test, y_train, y_test = train_test_split(df5, Y, test_size=0.24, random_state=42)
               
   import xgboost as xgb
           
           
   bst = xgb.XGBRegressor(max_depth=4, learning_rate=0.1, n_estimators=1000, silent=True, objective='reg:linear', )
   bst.fit(X_train,y_train)
   best_preds = bst.predict(X_test)
   print(i,r2_score(y_test,best_preds),mean_absolute_error(y_test,best_preds))
# Out:
# Open 0.41313842924522237 1.650096447296142
# High 0.7742061499557356 0.9119206164550766
# Low 0.3872326096955585 1.325781433074952
# Close 0.5089043635459581 1.348230831115723
# Volume 0.07261393218188195 6755565.375
# Adj Close 0.5390130405849562 1.3852173536071772
